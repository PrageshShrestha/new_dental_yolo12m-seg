# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11m-seg.pt")

# %%
#results = model.train(data="dataset/data.yaml", epochs=100, imgsz=960, batch=4, device='cuda')

# %%
# Out:
# image 1/1 c:\Users\user\Desktop\new_c\test.jpg: 512x960 1 11, 1 12, 1 13, 1 14, 1 15, 1 16, 1 17, 1 18, 1 21, 1 22, 1 23, 1 24, 1 25, 1 26, 1 27, 1 28, 1 31, 1 32, 1 33, 1 34, 1 35, 1 36, 1 37, 1 38, 1 41, 1 42, 1 43, 1 44, 1 45, 1 46, 1 47, 1 48, 38.4ms
# Speed: 2.1ms preprocess, 38.4ms inference, 16.8ms postprocess per image at shape (1, 3, 512, 960)
